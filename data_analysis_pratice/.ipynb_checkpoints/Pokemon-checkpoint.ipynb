# %%
# 分组计算

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\Kaifan\\Desktop\\Pokemon.csv")

# %%
g1 = df.groupby(['Type 1'])

# %%
g1

# %%
g1.first()
# Out:
#                              Name    Type 2  Total  HP  Attack  Defense  \
# Type 1
# Bug                      Caterpie    Flying    195  45      30       35
# Dark                      Umbreon    Flying    525  95      65      110
# Dragon                    Dratini    Flying    300  41      64       45
# Electric                  Pikachu     Steel    320  35      55       40
# Fairy                    Clefairy    Flying    323  70      45       48
# Fighting                   Mankey   Psychic    305  40      80       35
# Fire                   Charmander    Flying    309  39      52       43
# Flying    TornadusIncarnate Forme    Dragon    580  79     115       70
# Ghost                      Gastly    Poison    310  30      35       30
# Grass                   Bulbasaur    Poison    318  45      49       49
# Ground                  Sandshrew      Rock    300  50      75       85
# Ice                          Jynx   Psychic    455  65      50       35
# ...

# %%
g1.size()
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       27
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# dtype: int64

# %%
g1.groups
# Out:
# {'Bug': Int64Index([ 13,  14,  15,  16,  17,  18,  19,  51,  52,  53,  54, 132, 136,
#              137, 179, 180, 181, 182, 208, 219, 220, 228, 229, 230, 231, 232,
#              288, 289, 290, 291, 292, 307, 308, 314, 315, 316, 342, 343, 446,
#              447, 457, 458, 459, 460, 461, 462, 463, 520, 600, 601, 602, 603,
#              604, 605, 618, 619, 649, 650, 656, 657, 677, 678, 693, 697, 698,
#              717, 732, 733, 734],
#             dtype='int64'),
#  'Dark': Int64Index([212, 213, 233, 246, 247, 248, 284, 285, 326, 327, 392, 393, 478,
#              512, 549, 568, 569, 620, 621, 631, 632, 685, 686, 690, 691, 694,
#              695, 696, 756, 757, 793],
#             dtype='int64'),
#  'Dragon': Int64Index([159, 160, 161, 365, 366, 406, 407, 408, 409, 417, 418, 419, 420,
#              425, 426, 491, 492, 493, 494, 671, 672, 673, 682, 706, 707, 710,
#              711, 712, 774, 775, 776, 794],
#             dtype='int64'),
# ...

# %%
g1.describe()
# Out:
#          Attack                                                            \
#           count        mean        std   min    25%    50%     75%    max
# Type 1
# Bug        69.0   70.971014  37.040904  10.0  45.00   65.0   90.00  185.0
# Dark       31.0   88.387097  25.774247  50.0  65.00   88.0  100.00  150.0
# Dragon     32.0  112.125000  33.742622  50.0  86.25  113.5  134.25  180.0
# Electric   44.0   69.090909  23.764169  30.0  53.75   65.0   85.00  123.0
# Fairy      17.0   61.529412  29.751298  20.0  45.00   52.0   72.00  131.0
# Fighting   27.0   96.777778  28.290163  35.0  80.00  100.0  120.00  145.0
# Fire       52.0   84.769231  28.769275  30.0  62.25   84.5  101.00  160.0
# Flying      4.0   78.750000  37.500000  30.0  60.00   85.0  103.75  115.0
# Ghost      32.0   73.781250  29.629687  30.0  53.75   66.0   92.75  165.0
# Grass      70.0   73.214286  25.380520  27.0  55.00   70.0   93.50  132.0
# Ground     32.0   95.750000  33.059087  40.0  72.00   85.0  121.00  180.0
# ...

# %%
g1.get_group('Rock')
# Out:
#      Attack  Defense Generation   HP Legendary                       Name  \
# 80       80      100          1   40     False                    Geodude
# 81       95      115          1   55     False                   Graveler
# 82      120      130          1   80     False                      Golem
# 103      45      160          1   35     False                       Onix
# 149      40      100          1   35     False                    Omanyte
# 150      60      125          1   70     False                    Omastar
# 151      80       90          1   30     False                     Kabuto
# 152     115      105          1   60     False                   Kabutops
# 153     105       65          1   80     False                 Aerodactyl
# 154     135       85          1   80     False  AerodactylMega Aerodactyl
# 200     100      115          2   70     False                  Sudowoodo
# 265      64       50          2   50     False                   Larvitar
# ...

# %%
g2 = df.groupby(['Type 1','Type 2'])

# %%
g2.first()
# Out:
#                                     Name  Total   HP  Attack  Defense  \
# Type 1   Type 2
# Bug      Electric                 Joltik    319   50      47       50
#          Fighting              Heracross    500   80     125       75
#          Fire                   Larvesta    360   55      85       55
#          Flying               Butterfree    395   60      45       50
#          Ghost                  Shedinja    236    1      90       45
#          Grass                     Paras    285   35      70       55
#          Ground                  Nincada    266   31      45       90
#          Poison                   Weedle    195   40      35       30
#          Rock                    Shuckle    505   20      10      230
#          Steel                Forretress    465   75      90      140
#          Water                   Surskit    269   40      30       32
# Dark     Dragon                    Deino    300   52      65       50
# ...

# %%
for name,group in g1:
    print(name)
    print(group.shape)
    print("-----------")
# Out:
# Bug
# (69, 12)
# -----------
# Dark
# (31, 12)
# -----------
# Dragon
# (32, 12)
# -----------
# Electric
# (44, 12)
# -----------
# Fairy
# (17, 12)
# -----------
# Fighting
# (27, 12)
# -----------
# Fire
# (52, 12)
# -----------
# Flying
# (4, 12)
# -----------
# Ghost
# (32, 12)
# -----------
# Grass
# (70, 12)
# -----------
# Ground
# (32, 12)
# -----------
# Ice
# (24, 12)
# -----------
# Normal
# (98, 12)
# -----------
# Poison
# (27, 12)
# -----------
# Psychic
# (57, 12)
# -----------
# Rock
# (44, 12)
# -----------
# Steel
# (27, 12)
# -----------
# Water
# (112, 12)
# -----------

# %%
g1.mean()['HP']
# Out:
# Type 1
# Bug         56.884058
# Dark        66.806452
# Dragon      83.312500
# Electric    59.795455
# Fairy       74.117647
# Fighting    69.851852
# Fire        69.903846
# Flying      70.750000
# Ghost       64.437500
# Grass       67.271429
# Ground      73.781250
# Ice         72.000000
# Normal      77.275510
# Poison      68.037037
# Psychic     70.631579
# Rock        65.363636
# Steel       65.222222
# Water       72.062500
# Name: HP, dtype: float64

# %%
g1['HP'].mean()
# Out:
# Type 1
# Bug         56.884058
# Dark        66.806452
# Dragon      83.312500
# Electric    59.795455
# Fairy       74.117647
# Fighting    69.851852
# Fire        69.903846
# Flying      70.750000
# Ghost       64.437500
# Grass       67.271429
# Ground      73.781250
# Ice         72.000000
# Normal      77.275510
# Poison      68.037037
# Psychic     70.631579
# Rock        65.363636
# Steel       65.222222
# Water       72.062500
# Name: HP, dtype: float64

# %%
g1.agg(np.sum)
# Out:
#           Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Type 1
# Bug       26146  3925    4897     4880     3717     4471   4256
# Dark      13818  2071    2740     2177     2314     2155   2361
# Dragon    17617  2666    3588     2764     3099     2843   2657
# Electric  19510  2631    3040     2917     3961     3243   3718
# Fairy      7024  1260    1046     1117     1335     1440    826
# Fighting  11244  1886    2613     1780     1434     1747   1784
# Fire      23820  3635    4408     3524     4627     3755   3871
# Flying     1940   283     315      265      377      290    410
# Ghost     14066  2062    2361     2598     2539     2447   2059
# Grass     29480  4709    5125     4956     5425     4930   4335
# Ground    14000  2361    3064     2715     1807     2008   2045
# Ice       10403  1728    1746     1714     1861     1831   1523
# Normal    39365  7573    7200     5865     5470     6245   7012
# Poison    10903  1837    2034     1887     1652     1763   1730
# ...
