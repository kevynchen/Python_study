# %%
import pandas as pd

# %%
import numpy as np

# %%
pwd()
# Out:
# u'C:\\Users\\Kaifan\\python\\data_analysis_pratice'

# %%
pd.read_csv("C:\\Users\\Kaifan\\Desktop\\NBA.csv")
# Out:
#        ���                 Player  height  weight  \
# 0        0        Curly Armstrong   180.0    77.0
# 1        1           Cliff Barker   188.0    83.0
# 2        2          Leo Barnhorst   193.0    86.0
# 3        3             Ed Bartels   196.0    88.0
# 4        4            Ralph Beard   178.0    79.0
# 5        5             Gene Berce   180.0    79.0
# 6        6          Charlie Black   196.0    90.0
# 7        7            Nelson Bobb   183.0    77.0
# 8        8        Jake Bornheimer   196.0    90.0
# 9        9           Vince Boryla   196.0    95.0
# 10      10              Don Boven   193.0    95.0
# 11      11          Harry Boykoff   208.0   102.0
# 12      12            Joe Bradley   190.0    79.0
# 13      13            Bob Brannum   196.0    97.0
# 14      14             Carl Braun   196.0    81.0
# 15      15          Frankie Brian   185.0    81.0
# 16      16       Price Brookfield   193.0    83.0
# 17      17              Bob Brown   193.0    92.0
# ...

# %%
df = pd.read_csv("C:\\Users\\Kaifan\\Desktop\\NBA.csv",encoding='gbk')

# %%
df.head()
# Out:
#    序号           Player  height  weight                          collage  \
# 0   0  Curly Armstrong   180.0    77.0               Indiana University
# 1   1     Cliff Barker   188.0    83.0           University of Kentucky
# 2   2    Leo Barnhorst   193.0    86.0         University of Notre Dame
# 3   3       Ed Bartels   196.0    88.0  North Carolina State University
# 4   4      Ralph Beard   178.0    79.0           University of Kentucky
#
#      born   birth_city birth_state
# 0  1918.0          NaN         NaN
# 1  1921.0     Yorktown     Indiana
# 2  1924.0          NaN         NaN
# 3  1925.0          NaN         NaN
# 4  1927.0  Hardinsburg    Kentucky

# %%
pd.read_csv("C:\\Users\\Kaifan\\Desktop\\NBAtest.csv",header = None,names = ['seq','player','height','weight','coll','born','city','state'])
# Out:
#        seq                 player  height  weight  \
# 0        0        Curly Armstrong   180.0    77.0
# 1        1           Cliff Barker   188.0    83.0
# 2        2          Leo Barnhorst   193.0    86.0
# 3        3             Ed Bartels   196.0    88.0
# 4        4            Ralph Beard   178.0    79.0
# 5        5             Gene Berce   180.0    79.0
# 6        6          Charlie Black   196.0    90.0
# 7        7            Nelson Bobb   183.0    77.0
# 8        8        Jake Bornheimer   196.0    90.0
# 9        9           Vince Boryla   196.0    95.0
# 10      10              Don Boven   193.0    95.0
# 11      11          Harry Boykoff   208.0   102.0
# 12      12            Joe Bradley   190.0    79.0
# 13      13            Bob Brannum   196.0    97.0
# 14      14             Carl Braun   196.0    81.0
# 15      15          Frankie Brian   185.0    81.0
# 16      16       Price Brookfield   193.0    83.0
# 17      17              Bob Brown   193.0    92.0
# ...

# %%
df.head(6)
# Out:
#    序号           Player  height  weight                          collage  \
# 0   0  Curly Armstrong   180.0    77.0               Indiana University
# 1   1     Cliff Barker   188.0    83.0           University of Kentucky
# 2   2    Leo Barnhorst   193.0    86.0         University of Notre Dame
# 3   3       Ed Bartels   196.0    88.0  North Carolina State University
# 4   4      Ralph Beard   178.0    79.0           University of Kentucky
# 5   5       Gene Berce   180.0    79.0             Marquette University
#
#      born   birth_city birth_state
# 0  1918.0          NaN         NaN
# 1  1921.0     Yorktown     Indiana
# 2  1924.0          NaN         NaN
# 3  1925.0          NaN         NaN
# 4  1927.0  Hardinsburg    Kentucky
# 5  1926.0          NaN         NaN

# %%
df.tail(10)
# Out:
#         序号                 Player  height  weight  \
# 3912  3912       Denzel Valentine   198.0    96.0
# 3913  3913          Fred VanVleet   183.0    88.0
# 3914  3914  Taurean Waller-Prince   183.0    88.0
# 3915  3915            Okaro White   203.0    92.0
# 3916  3916       Isaiah Whitehead   193.0    96.0
# 3917  3917          Troy Williams   198.0    97.0
# 3918  3918           Kyle Wiltjer   208.0   108.0
# 3919  3919      Stephen Zimmerman   213.0   108.0
# 3920  3920            Paul Zipser   203.0    97.0
# 3921  3921            Ivica Zubac   216.0   120.0
#
#                               collage    born      birth_city  \
# 3912        Michigan State University  1993.0         Lansing
# 3913         Wichita State University  1994.0        Rockford
# 3914                              NaN  1994.0             NaN
# 3915         Florida State University  1992.0      Clearwater
# 3916            Seton Hall University  1995.0        Brooklyn
# ...

# %%
df['Player']
# Out:
# 0             Curly Armstrong
# 1                Cliff Barker
# 2               Leo Barnhorst
# 3                  Ed Bartels
# 4                 Ralph Beard
# 5                  Gene Berce
# 6               Charlie Black
# 7                 Nelson Bobb
# 8             Jake Bornheimer
# 9                Vince Boryla
# 10                  Don Boven
# 11              Harry Boykoff
# 12                Joe Bradley
# 13                Bob Brannum
# 14                 Carl Braun
# 15              Frankie Brian
# 16           Price Brookfield
# 17                  Bob Brown
# 18                 Jim Browne
# 19                 Walt Budko
# 20             Jack Burmaster
# 21               Tommy Byrnes
# 22               Bill Calhoun
# 23                Don Carlson
# 24              Bob Carpenter
# 25                Jake Carter
# 26                  Al Cervi*
# 27                John Chaney
# 28              Leroy Chollet
# 29                 Bill Closs
#                 ...
# ...

# %%
df['newcol'] = 1

# %%
df.head()
# Out:
#    序号           Player  height  weight                          collage  \
# 0   0  Curly Armstrong   180.0    77.0               Indiana University
# 1   1     Cliff Barker   188.0    83.0           University of Kentucky
# 2   2    Leo Barnhorst   193.0    86.0         University of Notre Dame
# 3   3       Ed Bartels   196.0    88.0  North Carolina State University
# 4   4      Ralph Beard   178.0    79.0           University of Kentucky
#
#      born   birth_city birth_state  newcol
# 0  1918.0          NaN         NaN       1
# 1  1921.0     Yorktown     Indiana       1
# 2  1924.0          NaN         NaN       1
# 3  1925.0          NaN         NaN       1
# 4  1927.0  Hardinsburg    Kentucky       1

# %%
del df['newcol']

# %%
df.head()
# Out:
#    序号           Player  height  weight                          collage  \
# 0   0  Curly Armstrong   180.0    77.0               Indiana University
# 1   1     Cliff Barker   188.0    83.0           University of Kentucky
# 2   2    Leo Barnhorst   193.0    86.0         University of Notre Dame
# 3   3       Ed Bartels   196.0    88.0  North Carolina State University
# 4   4      Ralph Beard   178.0    79.0           University of Kentucky
#
#      born   birth_city birth_state
# 0  1918.0          NaN         NaN
# 1  1921.0     Yorktown     Indiana
# 2  1924.0          NaN         NaN
# 3  1925.0          NaN         NaN
# 4  1927.0  Hardinsburg    Kentucky

# %%
df['hw'] = df['height'] + df['weight']

# %%
df.head()
# Out:
#    序号           Player  height  weight                          collage  \
# 0   0  Curly Armstrong   180.0    77.0               Indiana University
# 1   1     Cliff Barker   188.0    83.0           University of Kentucky
# 2   2    Leo Barnhorst   193.0    86.0         University of Notre Dame
# 3   3       Ed Bartels   196.0    88.0  North Carolina State University
# 4   4      Ralph Beard   178.0    79.0           University of Kentucky
#
#      born   birth_city birth_state     hw
# 0  1918.0          NaN         NaN  257.0
# 1  1921.0     Yorktown     Indiana  271.0
# 2  1924.0          NaN         NaN  279.0
# 3  1925.0          NaN         NaN  284.0
# 4  1927.0  Hardinsburg    Kentucky  257.0

# %%
df['hw'] = df['hw'] / 10

# %%
df.head()
# Out:
#    序号           Player  height  weight                          collage  \
# 0   0  Curly Armstrong   180.0    77.0               Indiana University
# 1   1     Cliff Barker   188.0    83.0           University of Kentucky
# 2   2    Leo Barnhorst   193.0    86.0         University of Notre Dame
# 3   3       Ed Bartels   196.0    88.0  North Carolina State University
# 4   4      Ralph Beard   178.0    79.0           University of Kentucky
#
#      born   birth_city birth_state    hw
# 0  1918.0          NaN         NaN  25.7
# 1  1921.0     Yorktown     Indiana  27.1
# 2  1924.0          NaN         NaN  27.9
# 3  1925.0          NaN         NaN  28.4
# 4  1927.0  Hardinsburg    Kentucky  25.7

# %%
df.columns
# Out:
# Index([         u'序号',      u'Player',      u'height',      u'weight',
#            u'collage',        u'born',  u'birth_city', u'birth_state',
#                 u'hw'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3922, step=1)

# %%
df.columns = [ 'Seq','Player','height','weight',
           'collage','born','birth_city','birth_state',
             'hw']

# %%
df.head()
# Out:
#    Seq           Player  height  weight                          collage  \
# 0    0  Curly Armstrong   180.0    77.0               Indiana University
# 1    1     Cliff Barker   188.0    83.0           University of Kentucky
# 2    2    Leo Barnhorst   193.0    86.0         University of Notre Dame
# 3    3       Ed Bartels   196.0    88.0  North Carolina State University
# 4    4      Ralph Beard   178.0    79.0           University of Kentucky
#
#      born   birth_city birth_state    hw
# 0  1918.0          NaN         NaN  25.7
# 1  1921.0     Yorktown     Indiana  27.1
# 2  1924.0          NaN         NaN  27.9
# 3  1925.0          NaN         NaN  28.4
# 4  1927.0  Hardinsburg    Kentucky  25.7

# %%
del df['Seq']

# %%
df.head()
# Out:
#             Player  height  weight                          collage    born  \
# 0  Curly Armstrong   180.0    77.0               Indiana University  1918.0
# 1     Cliff Barker   188.0    83.0           University of Kentucky  1921.0
# 2    Leo Barnhorst   193.0    86.0         University of Notre Dame  1924.0
# 3       Ed Bartels   196.0    88.0  North Carolina State University  1925.0
# 4      Ralph Beard   178.0    79.0           University of Kentucky  1927.0
#
#     birth_city birth_state    hw
# 0          NaN         NaN  25.7
# 1     Yorktown     Indiana  27.1
# 2          NaN         NaN  27.9
# 3          NaN         NaN  28.4
# 4  Hardinsburg    Kentucky  25.7

# %%
df.shape
# Out:
# (3922, 8)

# %%
df.dtypes
# Out:
# Player          object
# height         float64
# weight         float64
# collage         object
# born           float64
# birth_city      object
# birth_state     object
# hw             float64
# dtype: object

# %%
df_new = df.fillna(-1)

# %%
df_new.head()
# Out:
#             Player  height  weight                          collage    born  \
# 0  Curly Armstrong   180.0    77.0               Indiana University  1918.0
# 1     Cliff Barker   188.0    83.0           University of Kentucky  1921.0
# 2    Leo Barnhorst   193.0    86.0         University of Notre Dame  1924.0
# 3       Ed Bartels   196.0    88.0  North Carolina State University  1925.0
# 4      Ralph Beard   178.0    79.0           University of Kentucky  1927.0
#
#     birth_city birth_state    hw
# 0           -1          -1  25.7
# 1     Yorktown     Indiana  27.1
# 2           -1          -1  27.9
# 3           -1          -1  28.4
# 4  Hardinsburg    Kentucky  25.7

# %%
df.head()
# Out:
#             Player  height  weight                          collage    born  \
# 0  Curly Armstrong   180.0    77.0               Indiana University  1918.0
# 1     Cliff Barker   188.0    83.0           University of Kentucky  1921.0
# 2    Leo Barnhorst   193.0    86.0         University of Notre Dame  1924.0
# 3       Ed Bartels   196.0    88.0  North Carolina State University  1925.0
# 4      Ralph Beard   178.0    79.0           University of Kentucky  1927.0
#
#     birth_city birth_state    hw
# 0          NaN         NaN  25.7
# 1     Yorktown     Indiana  27.1
# 2          NaN         NaN  27.9
# 3          NaN         NaN  28.4
# 4  Hardinsburg    Kentucky  25.7

# %%
type(df['Player'])
# Out:
# pandas.core.series.Series

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0]
# Out:
# Player            Curly Armstrong
# height                        180
# weight                         77
# collage        Indiana University
# born                         1918
# birth_city                    NaN
# birth_state                   NaN
# hw                           25.7
# Name: 0, dtype: object

# %%
df['Player']
# Out:
# 0             Curly Armstrong
# 1                Cliff Barker
# 2               Leo Barnhorst
# 3                  Ed Bartels
# 4                 Ralph Beard
# 5                  Gene Berce
# 6               Charlie Black
# 7                 Nelson Bobb
# 8             Jake Bornheimer
# 9                Vince Boryla
# 10                  Don Boven
# 11              Harry Boykoff
# 12                Joe Bradley
# 13                Bob Brannum
# 14                 Carl Braun
# 15              Frankie Brian
# 16           Price Brookfield
# 17                  Bob Brown
# 18                 Jim Browne
# 19                 Walt Budko
# 20             Jack Burmaster
# 21               Tommy Byrnes
# 22               Bill Calhoun
# 23                Don Carlson
# 24              Bob Carpenter
# 25                Jake Carter
# 26                  Al Cervi*
# 27                John Chaney
# 28              Leroy Chollet
# 29                 Bill Closs
#                 ...
# ...

# %%
s = df['Player']

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3922, step=1)

# %%
s.values
# Out:
# array([u'Curly Armstrong', u'Cliff Barker', u'Leo Barnhorst', ...,
#        u'Stephen Zimmerman', u'Paul Zipser', u'Ivica Zubac'], dtype=object)

# %%
s1 = df['collage']

# %%
len(s1.unique())
# Out:
# 423

# %%
df['collage'].value_counts()
# Out:
# University of Kentucky                               89
# University of California, Los Angeles                86
# University of North Carolina                         67
# University of Kansas                                 59
# Duke University                                      56
# University of Notre Dame                             51
# Indiana University                                   49
# Syracuse University                                  49
# St. John's University                                48
# University of Louisville                             46
# Michigan State University                            45
# University of Arizona                                43
# University of Minnesota                              41
# Ohio State University                                39
# University of Michigan                               38
# University of Maryland                               36
# Villanova University                                 36
# ...

# %%
s2 = df['weight']

# %%
s2 > 80
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4       False
# 5       False
# 6        True
# 7       False
# 8        True
# 9        True
# 10       True
# 11       True
# 12      False
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21      False
# 22       True
# 23      False
# 24       True
# 25       True
# 26      False
# 27       True
# 28       True
# 29       True
#         ...
# 3892     True
# 3893     True
# 3894     True
# 3895     True
# 3896     True
# 3897     True
# 3898     True
# 3899     True
# 3900     True
# 3901     True
# 3902     True
# 3903     True
# 3904     True
# 3905     True
# 3906     True
# 3907     True
# 3908    False
# 3909     True
# 3910    False
# 3911     True
# 3912     True
# 3913     True
# 3914     True
# 3915     True
# 3916     True
# 3917     True
# 3918     True
# 3919     True
# 3920     True
# 3921     True
# ...

# %%
s2[s2 > 80]
# Out:
# 1        83.0
# 2        86.0
# 3        88.0
# 6        90.0
# 8        90.0
# 9        95.0
# 10       95.0
# 11      102.0
# 13       97.0
# 14       81.0
# 15       81.0
# 16       83.0
# 17       92.0
# 18      106.0
# 19       99.0
# 20       86.0
# 22       81.0
# 24       90.0
# 25       88.0
# 27       83.0
# 28       86.0
# 29       88.0
# 30       81.0
# 31       88.0
# 33       81.0
# 34       90.0
# 35       92.0
# 40       81.0
# 43       88.0
# 44       81.0
#         ...
# 3890     94.0
# 3891    111.0
# 3892    111.0
# 3893    108.0
# 3894     81.0
# 3895    111.0
# 3896    112.0
# 3897    107.0
# 3898     88.0
# 3899     83.0
# 3900     92.0
# 3901    108.0
# 3902    101.0
# 3903     95.0
# 3904    104.0
# 3905    104.0
# 3906    115.0
# 3907    115.0
# 3909    117.0
# 3911    100.0
# 3912     96.0
# 3913     88.0
# 3914     88.0
# 3915     92.0
# 3916     96.0
# 3917     97.0
# 3918    108.0
# 3919    108.0
# 3920     97.0
# 3921    120.0
# ...

# %%
a = {'name': 'kaifan','age': 21,'state': 'guangxi'}

# %%
pd.Series(a)
# Out:
# age           21
# name      kaifan
# state    guangxi
# dtype: object

# %%
b = np.array([1,2,3,4,5])

# %%
pd.Series(b)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
pd.Series(4)
# Out:
# 0    4
# dtype: int64

# %%
# ?pd.Series()

# %%
pd.DataFrame(a,index=[0])
# Out:
#    age    name    state
# 0   21  kaifan  guangxi

# %%
aa = {'A': {'name': 'kaifan','age': 21,'state': 'guangxi'},'B': {'name': 'qiqi','age': 21,'state': 'xiamen'}}

# %%
pd.DataFrame(aa)
# Out:
#              A       B
# age         21      21
# name    kaifan    qiqi
# state  guangxi  xiamen

# %%
bb = {'A': [1,2,3,4],'B': [5,6,7,8]}

# %%
pd.DataFrame(bb)
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
c = [[1,2,3],[4,5,6]]

# %%
pd.DataFrame(c)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
type(pd.DataFrame(s))
# Out:
# pandas.core.frame.DataFrame

# %%
# ?pd.DataFrame.from_dict

# %%
pd.DataFrame.from_dict(a,orient='index')
# Out:
#              0
# age         21
# name    kaifan
# state  guangxi
